# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
#read the Excel file to create a dataframe
dfx = pd.read_excel('/content/drive/My Drive/titanic.xlsx')

# %%
dfx
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df_fil = dfx[['Survived','Pclass','Name', 'Gender','Age', 'Fare']]

# %%
df_fil
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender   Age     Fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# ...

# %%
df_fil.describe()
# Out:
#          Survived      Pclass         Age       Fare
# count  887.000000  887.000000  887.000000  887.00000
# mean     0.385569    2.305524   29.471443   32.30542
# std      0.487004    0.836662   14.121908   49.78204
# min      0.000000    1.000000    0.420000    0.00000
# 25%      0.000000    2.000000   20.250000    7.92500
# 50%      0.000000    3.000000   28.000000   14.45420
# 75%      1.000000    3.000000   38.000000   31.13750
# max      1.000000    3.000000   80.000000  512.32920

# %%
df_fil['Pclass'].value_counts()
# Out:
# 3    487
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_fil['Age'].hist()

# %%
df_fil['Survived'].value_counts().plot(kind='bar')

# %%
df_fil['Gender'].value_counts().plot(kind='bar')

# %%
df_fil['Pclass'].value_counts().plot(kind='bar')

# %%
df_group1 = df_fil.groupby('Gender').mean()

# %%
df_group1
# Out:
#         Survived    Pclass        Age       Fare
# Gender
# female  0.742038  2.159236  27.719745  44.479818
# male    0.190227  2.385689  30.431361  25.633935

# %%
df_group2 = df_fil.groupby(['Gender','Pclass']).mean()

# %%
df_group2
# Out:
#                Survived        Age        Fare
# Gender Pclass
# female 1       0.968085  35.255319  106.125798
#        2       0.921053  28.980263   21.970121
#        3       0.500000  22.135417   16.118810
# male   1       0.368852  41.511639   67.226127
#        2       0.157407  30.493796   19.741782
#        3       0.137026  26.470612   12.695466

# %%
df_cont = pd.read_csv("/content/drive/My Drive/contributions_2012.csv", index_col=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_cont
# Out:
#            cmte_id    cand_id             cand_nm               contbr_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2        C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3        C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4        C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...            ...        ...                 ...                     ...
# 1001726  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 1001727  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 1001728  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 1001729  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 1001730  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                 contbr_city contbr_st   contbr_zip  \
# ...

# %%
df_cont.head(n=20)
# Out:
#       cmte_id    cand_id             cand_nm           contbr_nm  \
# 0   C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1   C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2   C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4   C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
# 5   C00410118  P20002978  Bachmann, Michelle      BECKMAN, JAMES
# 6   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 7   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 8   C00410118  P20002978  Bachmann, Michelle      COLLINS, SARAH
# 9   C00410118  P20002978  Bachmann, Michelle     COLEMAN, RONALD
# 10  C00410118  P20002978  Bachmann, Michelle  ATCHLEY, JR, KEITH
# 11  C00410118  P20002978  Bachmann, Michelle    FARNSWORTH, ROSS
# 12  C00410118  P20002978  Bachmann, Michelle   PRESTON, CLIFFORD
# ...

# %%
df_cont.shape
# Out:
# (1001731, 16)

# %%
df_cont.dtypes
# Out:
# cmte_id               object
# cand_id               object
# cand_nm               object
# contbr_nm             object
# contbr_city           object
# contbr_st             object
# contbr_zip            object
# contbr_employer       object
# contbr_occupation     object
# contb_receipt_amt    float64
# contb_receipt_dt      object
# receipt_desc          object
# memo_cd               object
# memo_text             object
# form_tp               object
# file_num               int64
# dtype: object

# %%
df_cont.contb_receipt_dt[:10]
# Out:
# 0    20-JUN-11
# 1    23-JUN-11
# 2    05-JUL-11
# 3    01-AUG-11
# 4    20-JUN-11
# 5    23-JUN-11
# 6    21-JUN-11
# 7    05-JUL-11
# 8    21-JUN-11
# 9    20-JUN-11
# Name: contb_receipt_dt, dtype: object

# %%
df_cont.contb_receipt_dt = pd.to_datetime(df_cont.contb_receipt_dt)

# %%
df_cont.dtypes
# Out:
# cmte_id                      object
# cand_id                      object
# cand_nm                      object
# contbr_nm                    object
# contbr_city                  object
# contbr_st                    object
# contbr_zip                   object
# contbr_employer              object
# contbr_occupation            object
# contb_receipt_amt           float64
# contb_receipt_dt     datetime64[ns]
# receipt_desc                 object
# memo_cd                      object
# memo_text                    object
# form_tp                      object
# file_num                      int64
# dtype: object

# %%
df_cont.contb_receipt_dt[:10]
# Out:
# 0   2011-06-20
# 1   2011-06-23
# 2   2011-07-05
# 3   2011-08-01
# 4   2011-06-20
# 5   2011-06-23
# 6   2011-06-21
# 7   2011-07-05
# 8   2011-06-21
# 9   2011-06-20
# Name: contb_receipt_dt, dtype: datetime64[ns]

# %%
df_cont['year'] = df_cont.contb_receipt_dt.dt.year #create an year column

# %%
df_cont
# Out:
#            cmte_id    cand_id             cand_nm               contbr_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1        C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2        C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3        C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4        C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...            ...        ...                 ...                     ...
# 1001726  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
# 1001727  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 1001728  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 1001729  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 1001730  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
#
#                 contbr_city contbr_st   contbr_zip  \
# ...

# %%
df_na = df_cont.dropna() #drops all rows with any null values

# %%
df_na.shape
# Out:
# (5760, 17)

# %%
df_na = df_cont.dropna(subset=['contbr_st'])

# %%
df_na.shape
# Out:
# (1001727, 17)
